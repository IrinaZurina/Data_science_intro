# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_performance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
students_performance = students_performance \
                                    .rename(columns=
                                            {'parental level of education': 'parental_level_of_education',
                                            'test preparation course': 'test_preparation_course',
                                            'math score': 'math_score',
                                            'reading score': 'reading_score',
                                            'writing score': 'writing_score'})
students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.math_score.hist()
# Out:
# <AxesSubplot: >

# %%
students_performance.plot.scatter(x = 'math_score', y = 'reading_score')
# Out:
# <AxesSubplot: xlabel='math_score', ylabel='reading_score'>

# %%
sns.lmplot(x = 'math_score', y = 'reading_score', data=students_performance)

# %%
sns.lmplot(x = 'math_score', y = 'reading_score', hue='gender', data=students_performance)

# %%
sns.lmplot(x = 'math_score', y = 'reading_score', hue='gender', data=students_performance, fit_reg=False)

# %%
ax = sns.lmplot(x = 'math_score', y = 'reading_score', hue='gender', data=students_performance, fit_reg=False)
ax.set_xlabels('Math scores')
ax.set_ylabels('Reading scores')

# %%
# ex_1.7.1
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
df.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
# Строки 15-21 - разные способы построить один и тот же график зависимости зарплаты от даты
df.income.plot()
# Out:
# <AxesSubplot: >

# %%
plt.plot(df.index, df.income)

# %%
df['income'].plot()

# %%
sns.lineplot(x=df.index, y=df.income)

# %%
sns.lineplot(data=df)

# %%
df.plot(kind='line')

# %%
df.plot()

# %%
# Ex 1.7.2
df1 = pd.read_csv('C:/Users/Ira Zurina/Downloads/dataset_209770_6 (1).txt', sep=' ')
df1.head()
# Out:
#              x            y
# 0  1283.002712  1503.437844
# 1   200.508129  1199.087585
# 2  1398.917215  1005.714291
# 3  1496.047686   804.198844
# 4   191.533898  1208.089094

# %%
df1.plot.scatter(x = 'x', y = 'y')
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %%
# 1.7.3 Скачайте данные, представляющие геномные расстояния между видами, и постройте тепловую карту, чтобы различия было видно наглядно.
gen_dist = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)
# Out:
# species0  species0    0.536029
#           species1    0.920292
#           species2    0.679708
#           species3    0.840606
#           species4    0.430842
# species1  species0    0.920292
#           species1    0.862417
#           species2    0.887593
#           species3    0.769754
#           species4    0.203214
# species2  species0    0.679708
#           species1    0.887593
#           species2    0.595156
#           species3    0.003435
#           species4    0.096052
# species3  species0    0.840606
#           species1    0.769754
#           species2    0.003435
#           species3    0.458870
#           species4    0.029251
# species4  species0    0.430842
#           species1    0.203214
#           species2    0.096052
#           species3    0.029251
#           species4    0.642109
# dtype: float64

# %%
sns.heatmap(gen_dist, cmap='viridis')
gen_dist_hm.xaxis.set_ticks_position('top')
gen_dist_hm.xaxis.set_tick_params(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 2
#       1 sns.heatmap(gen_dist, cmap='viridis')
# ----> 2 gen_dist_hm.xaxis.set_ticks_position('top')
#       3 gen_dist_hm.xaxis.set_tick_params(rotation=90)
#
# File E:\Data_Science\Stepik\Data_Science_intro\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'xaxis'

# %%
# 1..7.4 Скачайте датасэт с данными о героях из игры dota 2 и посмотрите на распределение их возможных ролей в игре (колонка roles). Постройте гистограмму, отражающую скольким героям сколько ролей приписывается (по мнению Valve, конечно) и напишите какое число ролей у большинства героев.
dota_heroes = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', index_col=0)
dota_heroes
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# ...

# %%
dota_heroes_roles = dota_heroes.loc[:, ['localized_name', 'roles']]
dota_heroes_roles['totalwords'] = dota_heroes_roles['roles'].str.split(', ').str.len()
dota_heroes_roles.hist(['totalwords'])
# Out:
# array([[<AxesSubplot: title={'center': 'totalwords'}>]], dtype=object)

# %%
iris_set = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)
iris_set
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
for column in iris_set:
       iris_set.hist([column])

# %%
sns.violinplot(y=iris_set["petal length"])
# Out:
# <AxesSubplot: ylabel='petal length'>

# %%
sns.pairplot(iris_set)
